# %%
# This file is to prepare the data for the district model
# For each block get the following information:

# Block Level Data 

# Electricity Demand 2020
# Electricity Demand 2021
# Electricity Demand 2022
# Gas Demand 2020
# Gas Demand 2021
# Gas Demand 2022
# District Heating Demand 2020
# District Heating Demand 2021
# District Heating Demand 2022
# Population 2020
# Population 2021
# Population 2022
# Relevant GML IDS for the block/district 
# Building Age 

# Building Level Data
# Number of Floors from Alkis file 
# Shape 
# Block ID

# %%
# Create Example Block File 
import pandas as pd

# %%
building_age = pd.read_csv(r'C:\Users\felix\Programmieren\tecdm\data\berlin\02_Gebäudealter.csv')
building_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 29 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   blknr       48 non-null     int64
#  1   bez         48 non-null     int64
#  2   bezname     48 non-null     object
#  3   plr         48 non-null     int64
#  4   blktypname  48 non-null     object
#  5   ewk         48 non-null     object
#  6   area        48 non-null     float64
#  7   datum       48 non-null     object
#  8   ueberw_dek  36 non-null     object
#  9   freistehen  16 non-null     float64
#  10  doppelhaus  5 non-null      float64
#  11  gereihtes   34 non-null     float64
#  12  anderertyp  26 non-null     float64
#  13  x_bis_1900  19 non-null     float64
#  14  x1901_1910  22 non-null     float64
#  15  x1911_1920  22 non-null     float64
#  16  x1921_1930  21 non-null     float64
#  17  x1931_1940  8 non-null      float64
#  18  x1941_1950  7 non-null      float64
# ...

# %%
electricity_demand = pd.read_csv(r'C:\Users\felix\Programmieren\tecdm\data\berlin\04_Electricity.csv')
electricity_demand
# Out:
#     fid  blknr  verbrauch_mwh  \
# 0     1  19017        126.159
# 1     2  19033       1275.717
# 2     3  19609      21127.807
# 3     4  19692       1360.709
# 4     5  19708        136.236
# 5     6  19742       5499.234
# 6     7  19759            NaN
# 7     8  19760            NaN
# 8     9  19901            NaN
# 9    10  20020            NaN
# 10   11  20021            NaN
# 11   12  20022        110.793
# 12   13  20023        173.854
# 13   14  20027        809.294
# 14   15  20028         23.155
# 15   16  20029        259.713
# 16   17  20030        249.643
# 17   18  20035        718.907
# 18   19  20036        496.584
# 19   20  20037        769.582
# 20   21  20038        985.165
# 21   22  20039        794.209
# 22   23  20040        612.016
# 23   24  20041        802.906
# 24   25  20042       1225.315
# 25   26  20043        799.847
# 26   27  20044        943.118
# 27   28  20045        642.910
# 28   29  20050        783.397
# 29   30  20051       1284.086
# ...

# %%
# Dictionary for renaming columns
rename_dict_el = {
    'fid': 'fid',
    'blknr': 'blknr',
    'verbrauch_mwh': 'el_consumption_mwh_2022',
    'ausgeschlossen': 'el_excluded_2022',
    'verbrauch_mwh2020': 'el_consumption_mwh_2020',
    'ausgeschlossen2020': 'el_excluded_2020',
    'verbrauch_mwh2021': 'el_consumption_mwh_2021',
    'ausgeschlossen2021': 'el_excluded_2021',
}

# Assuming `df` is your DataFrame
electricity_demand.rename(columns=rename_dict_el, inplace=True)

# %%
gas_demand = pd.read_csv(r'C:\Users\felix\Programmieren\tecdm\data\berlin\06_Gas.csv')
gas_demand.columns
# Out:
# Index(['blknr', 'bez', 'bezname', 'plr', 'blktypname', 'ewk', 'area', 'datum',
#        'fid', 'verbrauch_', 'ausgeschlo', 'verbrauc_1', 'ausgesch_1',
#        'verbrauc_2', 'ausgesch_2'],
#       dtype='object')

# %%
# Dictionary for renaming columns
# Check which year is what, 2022 can be identified here: https://energieatlas.berlin.de/ 
rename_dict_gas = {
    'fid': 'fid',
    'blknr': 'blknr',
    'verbrauch_': 'gas_consumption_mwh_2022',
    'ausgeschlo': 'gas_excluded_2022',
    'verbrauc_1': 'gas_consumption_mwh_2021',
    'ausgesch_1': 'gas_excluded_2021',
    'verbrauc_2': 'gas_consumption_mwh_2020',
    'ausgesch_2': 'gas_excluded_2020',
    'blknr' : 'blknr',
    'bez' : 'gas_bez',
    'bezname' : 'gas_bezname',
    'plr' : 'gas_plr',
    'blktypname' : 'gas_blktypname',
    'ewk' : 'gas_ewk',
    'area': 'gas_area',
    'datum' : 'gas_datum',
}


# Assuming `df` is your DataFrame
gas_demand.rename(columns=rename_dict_gas, inplace=True)

# %%
gas_demand.columns
# Out:
# Index(['blknr', 'gas_bez', 'gas_bezname', 'gas_plr', 'gas_blktypname',
#        'gas_ewk', 'gas_area', 'gas_datum', 'fid', 'gas_consumption_mwh_2022',
#        'gas_excluded_2022', 'gas_consumption_mwh_2021', 'gas_excluded_2021',
#        'gas_consumption_mwh_2020', 'gas_excluded_2020'],
#       dtype='object')

# %%
# Drop unnecessary columns
gas_demand.drop(columns=['gas_bez', 'gas_bezname', 'gas_plr', 'gas_blktypname', 'gas_ewk', 'gas_area', 'gas_datum'], inplace=True)

# %%
dh_demand = pd.read_csv(r'C:\Users\felix\Programmieren\tecdm\data\berlin\05_DistrictHeating.csv')

# Check this 

rename_dict_dh = { 
    'verbrauch_': 'dh_consumption_mwh2022',  
    'verbrauc_1': 'dh_consumption_mwh_2021',
    'verbrauc_2': 'dh_consumption_mwh_2020',
    'blknr': 'blknr',  
    'bez': 'dh_bez',
    'bezname': 'dh_bezname',
    'plr': 'dh_plr',
    'blktypname': 'dh_blktypname',
    'ewk': 'dh_ewk', 
    'area': 'dh_area',
    'datum': 'dh_datum',

}

dh_demand = dh_demand.rename(columns=rename_dict_dh)
dh_demand.columns
# Out:
# Index(['blknr', 'dh_bez', 'dh_bezname', 'dh_plr', 'dh_blktypname', 'dh_ewk',
#        'dh_area', 'dh_datum', 'dh_consumption_mwh2022',
#        'dh_consumption_mwh_2021', 'dh_consumption_mwh_2020', 'blknr_2',
#        'bez_2', 'bezname_2', 'plr_2', 'blktypna_1', 'ewk_2', 'area_2',
#        'datum_2'],
#       dtype='object')

# %%
dh_demand.drop(columns=['dh_bez', 'dh_bezname', 'dh_plr', 'dh_blktypname', 'dh_ewk', 'dh_area', 'dh_datum'], inplace=True)

# %%
inhabtiants_2020 = pd.read_csv(r'C:\Users\felix\Programmieren\tecdm\data\berlin\03_Inhabitants2020.csv')
inhabtiants_2021 = pd.read_csv(r'C:\Users\felix\Programmieren\tecdm\data\berlin\03_Inhabitants2021.csv')
inhabtiants_2022 = pd.read_csv(r'C:\Users\felix\Programmieren\tecdm\data\berlin\03_Inhabitants2022.csv')
inhabtiants_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   blknr       45 non-null     int64
#  1   bez         45 non-null     int64
#  2   bezname     45 non-null     object
#  3   plr         45 non-null     int64
#  4   blktypname  45 non-null     object
#  5   ewk         45 non-null     object
#  6   area        45 non-null     float64
#  7   datum       45 non-null     object
#  8   fid         45 non-null     int64
#  9   verbrauch_  33 non-null     float64
#  10  ausgeschlo  12 non-null     object
#  11  verbrauc_1  37 non-null     float64
#  12  ausgesch_1  8 non-null      object
#  13  verbrauc_2  37 non-null     float64
#  14  ausgesch_2  0 non-null      float64
#  15  fid_2       44 non-null     float64
#  16  schl5       44 non-null     float64
#  17  ew2021      44 non-null     float64
#  18  flalle      44 non-null     float64
# ...

# %%
inhabtiants_2021.columns
# Out:
# Index(['blknr', 'bez', 'bezname', 'plr', 'blktypname', 'ewk', 'area', 'datum',
#        'fid', 'verbrauch_', 'ausgeschlo', 'verbrauc_1', 'ausgesch_1',
#        'verbrauc_2', 'ausgesch_2', 'fid_2', 'schl5', 'ew2021', 'flalle',
#        'ew_ha_2021', 'typklar'],
#       dtype='object')

# %%
# keep ew (inhabitans) and blknr
inhabtiants_2020 = inhabtiants_2020[['ew2020', 'blknr']]    
inhabtiants_2021 = inhabtiants_2021[['ew2021', 'blknr']]    
inhabtiants_2022 = inhabtiants_2022[['ew2022', 'blknr']]

# %%
list_dfs = [building_age, dh_demand, electricity_demand, gas_demand, inhabtiants_2020, inhabtiants_2021, inhabtiants_2022]

# %%
merged_df = list_dfs[0]  # Start with the first DataFrame

for df in list_dfs[1:]:  # Iterate over the rest of the DataFrames
    print(df.info())
    merged_df = pd.merge(merged_df, df, on='blknr', how='inner')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   blknr                    45 non-null     int64
#  1   dh_consumption_mwh2022   25 non-null     float64
#  2   dh_consumption_mwh_2021  25 non-null     float64
#  3   dh_consumption_mwh_2020  26 non-null     float64
#  4   blknr_2                  45 non-null     int64
#  5   bez_2                    45 non-null     int64
#  6   bezname_2                45 non-null     object
#  7   plr_2                    45 non-null     int64
#  8   blktypna_1               45 non-null     object
#  9   ewk_2                    45 non-null     object
#  10  area_2                   45 non-null     float64
#  11  datum_2                  45 non-null     object
# dtypes: float64(4), int64(4), object(4)
# memory usage: 4.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 57 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   blknr                     48 non-null     int64
#  1   bez                       48 non-null     int64
#  2   bezname                   48 non-null     object
#  3   plr                       48 non-null     int64
#  4   blktypname                48 non-null     object
#  5   ewk                       48 non-null     object
#  6   area                      48 non-null     float64
#  7   datum                     48 non-null     object
#  8   ueberw_dek                36 non-null     object
#  9   freistehen                16 non-null     float64
#  10  doppelhaus                5 non-null      float64
#  11  gereihtes                 34 non-null     float64
#  12  anderertyp                26 non-null     float64
# ...

# %%
merged_df.drop_duplicates()
# Out:
#     blknr  bez                     bezname      plr blktypname  \
# 0   19017    4  Charlottenburg-Wilmersdorf  4300518      Block
# 1   19033    4  Charlottenburg-Wilmersdorf  4300517      Block
# 2   19609    4  Charlottenburg-Wilmersdorf  4300518      Block
# 3   19692    4  Charlottenburg-Wilmersdorf  4300518      Block
# 4   19708    4  Charlottenburg-Wilmersdorf  4300518      Block
# 5   19742    4  Charlottenburg-Wilmersdorf  4300518      Block
# 6   19742    4  Charlottenburg-Wilmersdorf  4300518      Block
# 7   19742    4  Charlottenburg-Wilmersdorf  4300518      Block
# 8   19759    4  Charlottenburg-Wilmersdorf  4300517      Block
# 9   19760    4  Charlottenburg-Wilmersdorf  4300517      Block
# 10  19901    4  Charlottenburg-Wilmersdorf  4300518  Bahnblock
# 11  20020    4  Charlottenburg-Wilmersdorf  4300517      Block
# 12  20021    4  Charlottenburg-Wilmersdorf  4300517      Block
# 13  20022    4  Charlottenburg-Wilmersdorf  4300517      Block
# ...

# %%
merged_df.to_csv(r'C:\Users\felix\Programmieren\tecdm\data\berlin\merged.csv', index=False)
